# %%
# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))
from scripts.news_eda import NewsEDA

# %% [markdown]
# ##### **Load the dataset and initialize EDA class**

# %%
# Load stock market news dataset
df = pd.read_csv("C:/Users/Admin/Desktop/KAIM/Week1/raw_analyst_ratings.csv")  
df.head()
# Out:
#    Unnamed: 0                                           headline  \
# 0           0            Stocks That Hit 52-Week Highs On Friday
# 1           1         Stocks That Hit 52-Week Highs On Wednesday
# 2           2                      71 Biggest Movers From Friday
# 3           3       46 Stocks Moving In Friday's Mid-Day Session
# 4           4  B of A Securities Maintains Neutral on Agilent...
#
#                                                  url          publisher  \
# 0  https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1  https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# 2  https://www.benzinga.com/news/20/05/16103463/7...         Lisa Levin
# 3  https://www.benzinga.com/news/20/05/16095921/4...         Lisa Levin
# 4  https://www.benzinga.com/news/20/05/16095304/b...         Vick Meyer
#
#                         date stock
# 0  2020-06-05 10:30:54-04:00     A
# 1  2020-06-03 10:45:20-04:00     A
# ...

# %%
# Initialize EDA class with the dataframe
eda = NewsEDA(df)

# %% [markdown]
# ##### **Descriptive Statistics**

# %%
# Get statistics like mean, min, max headline lengths to understand text variability
print(eda.calculate_headline_length())
# Out:
# count    1.407328e+06
# mean     7.312051e+01
# std      4.073531e+01
# min      3.000000e+00
# 25%      4.700000e+01
# 50%      6.400000e+01
# 75%      8.700000e+01
# max      5.120000e+02
# Name: headline_length, dtype: float64

# %%
# Visualize and rank publishers by article count to see who's most active
eda.count_articles_per_publisher(top_n=10)
# Out:
# publisher
# Paul Quintaro        228373
# Lisa Levin           186979
# Benzinga Newsdesk    150484
# Charles Gross         96732
# Monica Gerson         82380
#                       ...
# MoneyGeek                 1
# muathe                    1
# Robert Morris             1
# LeftCoastHedgie           1
# Jeremie Capron            1
# Name: count, Length: 1034, dtype: int64

# %%
# Bar chart of articles per weekday to identify publishing trends (e.g., weekend drops or event spikes)
eda.analyze_publication_dates()
# Out:
# day_of_week
# Thursday     289907
# Wednesday    289049
# Tuesday      285468
# Monday       254842
# Friday       208511
# Sunday        16078
# Saturday       7486
# Name: count, dtype: int64

# %% [markdown]
# ##### **Text Analysis**

# %%
# Run sentiment polarity scoring on headlines and visualize distribution (positive, neutral, negative)
eda.perform_sentiment_analysis()  
# Extract top keywords using Bag-of-Words for topic/theme exploration in headlines
print(eda.extract_keywords(max_features=20))
# Out:
# ['announces' 'benzinga' 'buy' 'downgrades' 'earnings' 'eps' 'est' 'market'
#  'mid' 'price' 'pt' 'raises' 'reports' 'sales' 'shares' 'stocks' 'trading'
#  'update' 'vs' 'week']

# %% [markdown]
# ##### **Time Series Analysis**

# %%
# Time series plot of daily article volume to spot trends and abnormal spikes during key events
eda.analyze_publication_trends()  
# Distribution of article count by hour to identify peak release hours critical for market response
eda.analyze_publishing_times()
# Out:
# hour
# 0.0    1351341
# Name: count, dtype: int64

# %% [markdown]
# ##### **Publisher Analysis**

# %%
# Word clouds of headline content from top publishers to explore their news focus
eda.generate_wordcloud_for_publishers(top_n=5)  
# Extract domain names from publisher emails (if any) to identify major contributing organizations
print(eda.extract_unique_domains())
# Out:
# domain
# benzinga.com              7937
# gmail.com                  139
# andyswan.com                 5
# investdiva.com               2
# tothetick.com                2
# eosdetroit.io                1
# forextraininggroup.com       1
# stockmetrix.net              1
# Name: count, dtype: int64
